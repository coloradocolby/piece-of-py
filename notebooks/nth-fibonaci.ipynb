# %%
# def nth_fib(n, memoize={1:0, 2:1}):
#     if n in memoize:
#         return memoize[n]
#     else:
#         memoize[n]=nth_fib(n-1, memoize) + nth_fib(n-2, memoize)
#         return memoize[n]

# without memoize

def nth_fib(n):
    if n == 1:
        return 0
    if n == 2:
        return 1
    return nth_fib(n-1) + nth_fib(n-2)

# fib(6) = fib(5) + fib(4)
# fib(5) = fib(4) + fib(3)
# fib(4) = fib(3) + fib(2)
# fib(3) = fib(2) + fib(1)
# fib(2) = fib(1) + fib(0)

# so...

# fib(2) = 1 + 0
# fib(3) = 1 + 1
# fib(4) = 2 + 1
# fib(5) = 3 + 2
# fib(6) = 5 + 3

# %%
nth_fib(150)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-4e35f434e14d> in <module>
# ----> 1 nth_fib(150)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#      13     if n == 2:
#      14         return 1
# ---> 15     return nth_fib(n-1) + nth_fib(n-2)
#      16
#      17 # fib(6) = fib(5) + fib(4)
#
# <ipython-input-45-226982bc9955> in nth_fib(n)
#       8 # without memoize
#       9
# ---> 10 def nth_fib(n):
#      11     if n == 1:
#      12         return 0
#
# KeyboardInterrupt:
